# %%
#1
n=int(input())
total=0
for i in range(1,n+1):
    total+=i    
print(total)
# Out:
# 36

# %%
#2
def is_prime(n):
    return n > 1 and all(n % i != 0 for i in range(2, int(n**0.5) + 1))
is_prime(int(input()))
# Out:
# False

# %%
#3
n=int(input())
a=1
for i in range(1,n+1):
    a *= i
print(a)
# Out:
# 2

# %%
#4
n=int(input())
a=1
if n<=0:
    n=-n
while n/10>=1:
    a+=1
    n=n/10
print(a)
# Out:
# 2

# %%
#5
n=int(input())
a=list(map(int,input(f"có {n} phần tử trong a:").split()))
print(print("I've found the meaning of life!" if 42 in a else "It's a joke!"))
# Out:
# I′ve found the meaning of life!

# %%
#6
a,b=map(int,input().split())
for i in range(a,b+1):
    if i>1 and all(i % j != 0 for j in range(2, int(i**0.5) + 1)):
        print(i)

# %%
#7
num = int(input())
uoc = []
for i in range(1, num + 1):
    if num % i == 0:
        uoc.append(i)
b=[]
for i in uoc:
    if i>1 and all(i % j != 0 for j in range(2, int(i**0.5) + 1)):
        b.append(i)
print(max(b))
# Out:
# 89

# %%
#8
def is_palidrome(n):
    return str(n) == str(n)[::-1]
def reverse_number(n):
    return int(str(n)[::-1])
def reverse_add_palidrome(n):
    count = 0
    while not is_palidrome(n):
        n += reverse_number(n)
        count += 1
    return count, n
n = int(input())
count, result = reverse_add_palidrome(n)
print(f"Count: {count}, Result: {result}")
# Out:
# Count: 24, Result: 8813200023188

# %%
#9
import math
n=int(input())
lst=[]
for i in range(1,n+1):
    r=math.isqrt(i)
    if r*r==i:
        lst.append(i)
if len(lst)==0 or lst==[1]:
    print("no number")
else:
    print(*lst)
# Out:
# 1 4 9 16 25

# %%
#w10
def collatz(n):
    length=1
    while n!=1:
        if n%2==0:
            n=n//2
        else:
            n=n*3+1
        length += 1
    return length
def longest_collatz(n):
     max_len=0
     a=1
     for i in range(1,n+1):
         len=collatz(i)
         if len > max_len:
             max_len=len
             a=i
     print(a,max_len)
longest_collatz(int(input()))
# Out:
# 9 20

# %%
#W11
n = int(input())
count = 0

i = 2
while i * i <= n:
    if n % i == 0:
        count += 1
        j = n // i
        if j != i and j % 2 == 0:
            count += 1
    i += 2  

if n % 2 == 0:
    count += 1

print(count)

# %%
#w12
money,months=map(int,input().split())
summoney=money*(1+0.7/100)**(months)
print(int(summoney))

# %%
#w13
a, b = map(int, input().split())

sumA = 0
sumB = 0
for i in range(1, a):
    if a % i == 0:
        sumA += i
for i in range(1, b):
    if b % i == 0:
        sumB += i
if sumA == b and sumB == a:
    print("true")
else:
    print("false")
# Out:
# false

# %%
#w14
m, n = map(int, input().split())

ucln = 1
for i in range(1, min(m, n) + 1):
    if m % i == 0 and n % i == 0:
        ucln = i

print(ucln)
# Out:
# 4

# %%
#w15
c,d=map(int,input().split())
a=2*c-d/2
b=d/2-c
if a==int(a)and b==int(b):
    print(int(a),int(b),end=" ")
else:
    print("invalid")

# %%
#w16
for i in range(1,101):
    if i%6==0:
        print(i,end=" ")

# %%
#w17
a=int(input())
for i in range(1,10):
    print(f"{a}*{i}={a*i}")

# %%
#w18
a,b=map(int,input().split())
for i in range(1,a+1):
    if a%i==0 and b%i==0:
        print(i,end=" ")

# %%
#w19
n=int(input())
i=2
while i<n and i%2==0:
    print(i,end=" ")
    i+=2

# %%
#w20
n=int(input())
if n>0 and (n&(n-1))==0:
    print(" ở dạng 2^k")
else:
     print("ko ở dạng 2^k")
# Out:
#  ở dạng 2^k

# %%
#w21
n=int(input())
a=0
for i in str(n):
    a+=int(i)
print(a)

# %%
#w22
n=int(input())
a=0
b=0
for i in str(n):
    if int(i)%2==0:
        a+=1
    else:
        b+=1
print(f" số chẵn là {a},số lẻ là {b}")

# %%
#w23
n=int(input())
k=0
while k*(k+1)/2 < n:
    k+=1
print(k-1)

# %%
#w24
lst=[]
while True:
    n=int(input())
    if n==-1:
        break
    lst.append(n)
print(max(lst),min(lst))

# %%
#w26
a=int(input())
x,y=0,1
while True:
    next=x+y
    x,y=y,next
    if y>=a:
        break
print(x)

# %%
#W25
lst=[]
n=1
while n!=-1:
  n=int(input())
  lst.append(n)
lst.remove(-1)
print(max(lst),min(lst))

# %%
#W27
a=input()
count=0
for i in a:
  if i != ' ':
    count+=1
print(count)
# Out:
# 10

# %%
#w28
a=input()
for ch in a:
    if ch != ' ':
       print(ch,end='')
    else:
        break

# %%
#w29
a=input()
lst=a.split(",")
lst1=[int(x) for x in lst]
print(sum(lst1))
# Out:
# 15

# %%
#w30
s=input()
a=0
b=0
c=0
for i in s:
 if i.isupper():
  a+=1
 if i.islower():
  b+=1
 if i.isdigit():
  c+=1
print(a,b,c)

# %%
#w31
a=input()
lst=[]
for i in a:
  if i.isdigit():
    lst.append(int(i))
print(sum(lst))

# %%
#w32
a=input()
has_upper=True
has_lower=True
has_digit=True
for i in a:
    if i.isupper():
        has_upper = True
    elif i.islower():
        has_lower = True
    elif i.isdigit():
        has_digit = True
if len(a)>6 and has_upper and has_lower and has_digit:
  print("a là mật khẩu mạnh")

# %%
#w33
a=input()
part=[a[i:i+3] for i in range(0,len(a),3) ]
newa='.'.join(part)
print(newa)

# %%
#w34
a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")

# tìm vị trí xuất hiện chuỗi b trong a (tự làm, không dùng a.find)
pos = -1
for i in range(len(a) - len(b) + 1):
    if a[i:i+len(b)] == b:
        pos = i
        break

# xóa nếu tìm thấy
if pos != -1:
    a = a[:pos] + a[pos+len(b):]

print("Chuỗi a sau khi xóa:", a)
