# %%
#W10A1:
a,b=map(int,input().split())
try:
  ket_qua=a/b
  print(f"{ket_qua:.2f}")
except ZeroDivisionError:
  print("Loi chia khong")
# Out:
# 10 0
# Loi chia khong

# %%
#W10A2:
try:
  n=int(input())
  my_list=list(map(int,input().split()))
  print(my_list[n])
except IndexError:
  print("IndexError")
# Out:
# 5
# 1 2 3 4 5 6
# 6

# %%
#W10A4:
try:
  a,b=map(int,input().split())
  print(a+b)
except ValueError:
  print("ValueError")
else:
  print("Khong co loi")
finally:
  print("Ket thuc chuong trinh")
# Out:
# 3 4.8
# ValueError
# Ket thuc chuong trinh

# %%
#W10A5:
lst=input().split()
result=[]
for x in lst:
  try:
    result.append(int(x))
  except:
    print(f"ValueError, cho {x} cut")
print(*result)
# Out:
# 1 2 3 4.0 6.44 4 0.7 9
# ValueError, cho 4.0 cut
# ValueError, cho 6.44 cut
# ValueError, cho 0.7 cut
# 1 2 3 4 9

# %%
#w10a6:
x=float(input())
try:
  if x>=0:
    ket_qua=x**0.5
    print(f"{ket_qua:.2f}")
  else:
    raise ValueError
except ValueError:
  print("So am")
# Out:
# -3
# So am

# %%
#W10A7:
x=input()
try:
  if int(x)>=0:
    print(2025-int(x))
  else:
    raise ValueError
except ValueError:
  print("Tuoi khong hop le")
# Out:
# abcde
# Tuoi khong hop le

# %%
try:
    x = int(input())
    if x <= 0:
        raise ValueError
    print(2025 - x)
except ValueError:
    print("Tuoi khong hop le")
# Out:
# 8
# 2017

# %%
#W10A8:
try:
  file=input()
  if file.endswith(".txt") or file.endswith(".zip"):
    print("File ok")
  else:
    raise ValueError
except ValueError:
  print("File khong hop le")
# Out:
# ima.jpg
# File khong hop le

# %%
#W10A9:
x=input()
try:
  print(int(x))
except ValueError:
  print("Chuoi khong hop le")
# Out:
# 12301
# 12301

# %%
#W10A10:
N=int(input())
a=list(map(int,input().split()))
try:
  if len(set(a))==len(a)==N:
    print(sum(a))
  else:
    raise ValueError
except ValueError:
  print("Mang khong hop le")
# Out:
# 4
# 10 20 30 40
# 100
